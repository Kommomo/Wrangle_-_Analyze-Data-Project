# %% [markdown]
# # Act Report

# %% [markdown]
# ### Introduction
#
# This report is created to communicate all the insights and display the visualizations generated from my wrangled data 'twitter_archive_master.csv' file. This wrangled data utilized datasets from the tweet archive of Twitter user @dog_rates, also known as WeRateDogs. WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog. These ratings have a numerator of 10 and WeRateDogs has over 4 million followers and has received international media coverage.

# %% [markdown]
# I will be exploring this wrangled data to determine what factors influence high ratings. My chosen dependent variable is rating_denominator(rating) and Independent variables are source and dog_stage.
#
# I explored these variables and the associations between them to answer the following research questions

# %% [markdown]
# - RQ1. What source has the highest number of tweets?
#
# - RQ2. Does a particular dog stage have higher tweets?
#
# - RQ3. What is the top rating?
#
# - RQ4. Is there a correlation between ratings and dog stage?
#
# - RQ5. Is there a correlation between ratings and source?

# %% [markdown]
# #### Research Question 1: What source has the highest number of tweets?

# %% [markdown]
# ![1-2.JPG](attachment:1-2.JPG)

# %% [markdown]
# ##### Conclusion
#
# We can see from both our analysis and visualization that the source with the highest number of tweets is Twitter for iphone with 1915 tweets out of 1954 tweets

# %% [markdown]
# #### Research Question 2: Does a particular dog stage have higher tweets?

# %% [markdown]
# ![2-2.JPG](attachment:2-2.JPG)

# %% [markdown]
# ##### Conclusion
#
# We can see from both our analysis and visualization that pupper dog_stage has the highest number of tweets with 201 tweets out of 303 tweets, followed by doggo and puppo with 63 and 22 respectively

# %% [markdown]
# #### Research Question 3: What is the top rating?

# %% [markdown]
# ![3-2.JPG](attachment:3-2.JPG)

# %% [markdown]
# ##### Conclusion
#
# We can see from both our analysis and visualization that the the top rating is 12/10 with 446 tweets, followed closely by 10/10 and 11/10

# %% [markdown]
# #### Research Question 4: Is there a correlation between ratings and dog stage?

# %% [markdown]
# ![4.JPG](attachment:4.JPG)

# %% [markdown]
# ##### Conclusion
#
# We can see from both our analysis and visualization that there is a strong correlation between ratings and dog_stage as the combination of pupper dog_stage and 12/10 rating have the highest number of tweets. Hence, dog_stage strongly influnces the rating of the dog.

# %% [markdown]
# #### Research Question 5: Is there a correlation between ratings and source?

# %% [markdown]
# ![5-2.JPG](attachment:5-2.JPG)

# %% [markdown]
# ##### Conclusion
#
# We can see from both our analysis and visualization that the there is no correlation between ratings and source. This implies that the tweet source does not influence the rating of the dog
